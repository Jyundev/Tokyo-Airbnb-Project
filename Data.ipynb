# %%
import pandas as pd
import os
import json

# %%
basePath = '/Users/genie/Documents/COLLABORATION/Tokyo-Airbnb-Project/csv/AirbnbTokyoInside/'
listings_detail_path = os.path.join(basePath, 'listings_detail.csv')
listings_path = os.path.join(basePath,'listings.csv')
calendar_path = os.path.join(basePath,'calendar.csv')
neighbourhoods_path = os.path.join(basePath,'neighbourhoods.csv')
reviews_detail_path = os.path.join(basePath,'reviews_detail.csv')
reviews_path = os.path.join(basePath,'reviews.csv')

# %%
listings_detail = pd.read_csv(listings_detail_path)
listings = pd.read_csv(listings_path)
calendar = pd.read_csv(calendar_path)
neighbourhoods= pd.read_csv(neighbourhoods_path)
reviews_detail = pd.read_csv(reviews_detail_path)
reviews = pd.read_csv(reviews_path)
display(listings_detail.head(1), listings.head(1), calendar.head(1), neighbourhoods.head(1), reviews_detail.head(1), reviews.head(1))
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  197677  https://www.airbnb.com/rooms/197677  20231227173752   2023-12-28
#
#         source                                               name  \
# 0  city scrape  Rental unit in Sumida · ★4.77 · 1 bedroom · 2 ...
#
#    description neighborhood_overview  \
# 0          NaN                   NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/38437056/d27f...   964081  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.83                   4.54                4.79
#
#       license instant_bookable calculated_host_listings_count  \
# 0  M130003350                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
#
#   calculated_host_listings_count_private_rooms  \
# ...

# %%
with open(basePath+'neighbourhoods.geojson') as f:
    json_f = json.loads(f.read()) # json 라이브러리 이용

geojsontokyo = pd.DataFrame(json_f)
geojsontokyo = pd.read_json(basePath+'neighbourhoods.geojson')
geojsontokyo
# Out:
#                  type                                           features
# 0   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 1   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 2   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 3   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 4   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# ..                ...                                                ...
# 57  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 58  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 59  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 60  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 61  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
#
# [62 rows x 2 columns]
